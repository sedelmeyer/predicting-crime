# %%
import os
import urllib
import requests
import zipfile
from pathlib import PurePath

from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# set path variables
DATA_ROOT = '../data'
parent_dir = os.path.join(DATA_ROOT, 'raw')
inventory_filepath = os.path.join(DATA_ROOT, 'data-inventory.csv')

# %%
# read data inventory to dataframe
inventory_df = pd.read_csv(inventory_filepath)

# %%
# view summary of data inventory
print(inventory_df.info())
inventory_df.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 13 columns):
# id                  47 non-null int64
# category            47 non-null object
# access              47 non-null object
# source              44 non-null object
# directory           47 non-null object
# sub-directory       47 non-null object
# filename            44 non-null object
# zipfile             37 non-null float64
# page-url            47 non-null object
# data-url            44 non-null object
# reference           32 non-null object
# description         44 non-null object
# access-confirmed    44 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 4.9+ KB
# None
#    id                     category    access source directory sub-directory  \
# 0   1  boston property assessments  download   data       raw      property
#
#            filename  zipfile  \
# 0  fy19-assessments      0.0
#
#                                             page-url  \
# 0  https://data.boston.gov/dataset/property-asses...
#
#                                             data-url  \
# 0  https://data.boston.gov/dataset/e02c44d2-3c64-...
#
#                                            reference  \
# 0  , https://data.boston.gov/dataset/e02c44d2-3c6...
#
#                                          description access-confirmed
# 0  Gives property, or parcel, ownership together ...       2019-11-07

# %%
# subset data inventory to include just 'downloads'
cols = ['sub-directory', 'filename', 'zipfile', 'data-url', 'source']
download_df = inventory_df.loc[inventory_df['access']=='download'][cols]

# %%
# define functions for performing data downloads

def make_download_dict(inventory, parent):
    """
    """
    subdirs = list(set(inventory['sub-directory']))
    inventory['file-type'] = download_df['data-url'].apply(
        lambda x: os.path.join(*PurePath(x).suffixes)
    )
    
    download_dict = {
        subdir: {
            filename: {
                'url': url,
                'filepath': os.path.join(parent, subdir, ''.join([filename, suffix])),
                'is_zip': is_zip
            }
            for filename, url, suffix, is_zip in zip(
                inventory.loc[inventory_df['sub-directory'] == subdir]['filename'],
                inventory.loc[inventory_df['sub-directory'] == subdir]['data-url'],
                inventory.loc[inventory_df['sub-directory'] == subdir]['file-type'],
                inventory.loc[inventory_df['sub-directory'] == subdir]['zipfile'],
            )
        } for subdir in subdirs
    }
    
    return download_dict


def make_subdirs(download_dict, parent, verbose=True):
    """
    """
    # create list of current top-level files and directories
    existing = os.listdir(parent)

    # check for ./data/ dir and create if it doesn't exist
    [
        os.mkdir(os.path.join(parent, subdir))
        for subdir in download_dict.keys() if not subdir in existing 
    ]
    
    # save new list of files and directories, as well is difference
    new_existing = os.listdir(parent)
    new_added = list(set(new_existing) - set(existing))
    
    # print summary results
    if verbose:
        if len(new_added) > 0:
            print('The following sub-directories were added to {}:'.format(parent))
            for subdir in new_added:
                print(subdir)
            print()
        else:
            print(
                'No directories have been created. All target directories already '\
                'exist locally\n'
            )
    
    return new_existing, new_added


def download_datafiles(download_dict, parent, exclude_subdir='shapefile', verbose=True):
    """
    """
    subdirs = [
        subdir for subdir in list(download_dict.keys())
        if subdir not in exclude_subdir
    ]
    downloaded = dict()
    
    for subdir in subdirs:
        for filename, download in download_dict[subdir].items():
            if not os.path.exists(download['filepath']):
                if verbose:
                    print(
                        'Downloading {0} data to {1}'.format(filename, download['filepath'])
                    )                
                downloaded[filename] = [
                    urllib.request.urlretrieve(
                        download['url'],
                        download['filepath'],
                    )
                ]
    
    if verbose:
        if len(downloaded)==0:
            print(
                'No datafiles have been downloaded. All target files already exist locally.\n'
            )
        else:
            print(
                '{0} data files have been downloaded and stored locally.\n'.format(
                    len(downloaded)
                )
            )
    
    return downloaded


def download_shapefiles(download_dict, parent, target_subdir='shapefile', verbose=True):
    """
    """
    downloaded = dict()
    
    for filename, download in download_dict[target_subdir].items():
        if not os.path.exists(download['filepath']):
            if verbose:
                print(
                    'Downloading {0} shapefile to {1}'.format(filename, download['filepath'])
                )                
            
            # download shape zipfile to directory
            downloaded[filename] = [
                urllib.request.urlretrieve(
                    download['url'],
                    download['filepath'],
                )
            ]
            
            # create target sub-directory for extracting zipfile
            shapedir = os.path.join(os.path.dirname(download['filepath']), filename)
            if not os.path.exists(shapedir):
                os.mkdir(shapedir)
            
            # extract zipfile to target sub-directory
            with zipfile.ZipFile(download['filepath'], 'r') as zipobj:

                if verbose:
                    print(
                        '\t...extracting shapefile zip archive to {0}'.format(shapedir)
                    )                

                # extract all files
                zipobj.extractall(shapedir)

    if verbose:
        if len(downloaded)==0:
            print(
                'No shapefiles have been downloaded. All target files already exist locally.\n'
            )
        else:
            print(
                '{0} shapefiles have been downloaded and extracted locally.\n'.format(
                    len(downloaded)
                )
            )
            
    return downloaded

# %%
# create download dictionary
download_dict = make_download_dict(download_df, parent_dir)

# make required sub-directories in parent directory
listdirs, added = make_subdirs(download_dict, parent_dir)

# download data files to target sub-directories
downloaded_data_confirmation = download_datafiles(download_dict, parent_dir)

# download and extract shapefiles to target sub-directories
downloaded_shape_confirmation = download_shapefiles(download_dict, parent_dir)
# Out:
# No directories have been created. All target directories already exist locally
#
# No datafiles have been downloaded. All target files already exist locally.

# %%
exclude = ['shapefile', 'crime']
list_keys = list(download_dict.keys())
[
    key for key in list_keys
    if key not in exclude
]
# Out:
# ['bpd-fio', 'boston', 'property']

# %%
def make_source_inventory():
    """"""
    raise NotImplementedError

def make_local_inventory():
    """"""
    raise NotImplementedError

def make_local_directory():
    """"""
    raise NotImplementedError

def check_local_data():
    """"""
    raise NotImplementedError
    
def download_source_data():
    """"""
    raise NotImplementedError

def check_additional_sources():
    """"""

# %%
url = 'https://data.boston.gov/dataset/property-assessment'
my_page = requests.get(url)

# %%
my_page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(my_page.content, 'html.parser')

# %%
soup.prettify()[:500]
# Out:
# '<!DOCTYPE html>\n<!--[if IE 7]> <html lang="en" class="ie ie7"> <![endif]-->\n<!--[if IE 8]> <html lang="en" class="ie ie8"> <![endif]-->\n<!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html lang="en">\n <!--<![endif]-->\n <head>\n  <!--[if lte ie 8]><script type="text/javascript" src="/fanstatic/vendor/:version:2019-08-09T21:00:46/html5.min.js"></script><![endif]-->\n  <link href="/fanstatic/vendor/:version:2019-08-09T21:00:46/select2/select2.css" rel="stylesheet" typ'

# %%
dataset_resources = soup.find('section', attrs={'id':'dataset-resources'})

# %%
resources = dataset_resources.find_all('li', attrs={'class': 'resource-item'})

# %%
resource_names = [resource.find('a', attrs={'class': 'heading'}).get('title') for resource in resources]

# %%
resource_urls = [resource.find('a', attrs={'btn btn-primary'}).get('href') for resource in resources]

# %%
resource_exts  = [os.path.splitext(resource_url)[1] for resource_url in resource_urls]

# %%
resource_types = ['data' if resource_ext in ['.csv', '.txt'] else 'key' for resource_ext in resource_exts]

# %%
resource_filenames = [
    ''.join([resource.lower().replace(' ', '-'), resource_ext])
    for resource, resource_ext
    in zip(resource_names, resource_exts)
]

# %%
inventory_dict = {
    'resource': resource_names,
    'filename': resource_filenames,
    'filetype': resource_types,
    'url': resource_urls,
}

# %%
inventory_df = pd.DataFrame(inventory_dict)

# %%
[a.get('href') for a in soup.find_all('a', attrs={'btn btn-primary'})]
# Out:
# ['https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/d6c1268c-cd83-4dc3-a914-bba1ed59da6d/download/propertyoccupancycodes.pdf',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/695a8596-5458-442b-a017-7cd72471aade/download/fy19fullpropassess.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/bac18ae6-b8fd-4cd3-a61c-c5e1a11f716c/download/property-assessment-fy2019-data-key.pdf',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/fd351943-c2c6-4630-992d-3f895360febd/download/ast2018full.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/b8e32ddf-671f-4a35-b99f-c060bae958e5/download/property-assessment-fy2018-data-key.pdf',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/062fc6fa-b5ff-4270-86cf-202225e40858/download/property-assessment-fy2017.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/d195dc47-56f6-437c-80a8-7acbb8a2aa6d/download/property-assessment-fy2017-data-key.pdf',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/cecdf003-9348-4ddb-94e1-673b63940bb8/download/property-assessment-fy2016.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/dbdc1bd8-60af-4913-a788-5f91cb68541b/download/assessing-property-data-key-2016.pdf',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/bdb17c2b-e9ab-44e4-a070-bf804a0e1a7f/download/property-assessment-fy2015.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/ddd1d6fa-6cdd-493b-85b5-b4b91a1de553/download/assessingpropertydatakey-7.pdf',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/7190b0a4-30c4-44c5-911d-c34f60b22181/download/property-assessment-fy2014.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/4e389dbd-3cc4-4268-ac57-759d91e574a9/download/fy14assessingdataguideandoccupancycodes.pdf',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/425fd527-e26b-49c9-853c-1c4d3d2bdd97/download/property-assessment-fy13.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/4326ca95-09ec-42e0-8cee-f048e00e6728/download/property-assessment-fy12.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/110e8ded-d7cd-40d2-a72c-e4f3c7e9c541/download/property-assessment-fy11.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/738ece37-5ae0-4f04-bf69-eca3ae1940b2/download/property-assessment-fy10.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/1a374bd0-1ff9-4d1a-8727-ddfc201254fe/download/property-assessment-fy09.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/81f34da8-ec6d-45f6-8d6c-65c57e71023e/download/property-assessment-fy08.csv',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/b3862082-216b-4a24-9f31-f47782079c3c/download/data2007-lite.txt',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/abab36a5-3e34-4262-8264-5f006e73ba6b/download/fy-07-lite-version.pdf',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/327af2fd-e386-4822-8a7f-aaab6d4d2c62/download/data2006lite.txt',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/cc02fad6-b0c6-4878-95b0-2f8ec4600683/download/2006-cdrom-lite-version.doc',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/5bfe4ca0-71c0-4751-bdcf-dad4d58445e0/download/data2005-lite.txt',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/8d4656e0-7ce0-49a6-8635-a9e9099559ac/download/2005-cdrom-lite-version.doc',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/d3be93ad-7939-4425-8b3b-73b69a747fa4/download/data2004-lite.txt',
#  'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/c50c981f-a512-47ab-b8d4-af95ce90948a/download/2004-cdrom-lite-version.doc']

# %%
DATA_ROOT = '../data/raw/'
raw_dir = 'bos_analyze'
filename = 'SAMaddresses'
data_url = 'http://bostonopendata-boston.opendata.arcgis.com/datasets/b6bffcace320448d96bb84eabb8a075f_0.csv'
directories = os.listdir(DATA_ROOT)

orig_filename = os.path.basename(data_url)
new_filename = ''.join([filename, os.path.splitext(orig_filename)[1]])
filepath_sam = os.path.join(DATA_ROOT, raw_dir, new_filename)

# check for bos_analyze
if not raw_dir in directories:
    os.mkdir(os.path.join(DATA_ROOT, raw_dir))

    local_filename, headers = urllib.request.urlretrieve(
        data_url,
        filepath
    )

# %%
# Out:
# ['../data/raw/',
#  '../data/raw/bos_analyze',
#  '../data/raw/bos_analyze/property_assess',
#  '../data/raw/census']

# %%
DATA_ROOT = '../data/raw/'
raw_dir = 'bos_analyze/property_assess'
filename = 'fy19fullpropassess'
data_url = 'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/'\
'resource/695a8596-5458-442b-a017-7cd72471aade/download/fy19fullpropassess.csv'
directories = os.listdir(DATA_ROOT)

orig_filename = os.path.basename(data_url)
new_filename = ''.join([filename, os.path.splitext(orig_filename)[1]])
filepath_prop = os.path.join(DATA_ROOT, raw_dir, new_filename)

# check for bos_analyze
if not raw_dir in [i[0] for i in os.walk(DATA_ROOT)]:
    os.mkdir(os.path.join(DATA_ROOT, raw_dir))
    local_filename, headers = urllib.request.urlretrieve(
        data_url,
        filepath
    )
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-43-6356c22a1c6e> in <module>
#      12 # check for bos_analyze
#      13 if not raw_dir in [i[0] for i in os.walk(DATA_ROOT)]:
# ---> 14     os.mkdir(os.path.join(DATA_ROOT, raw_dir))
#      15
#      16     local_filename, headers = urllib.request.urlretrieve(
#
# FileExistsError: [Errno 17] File exists: '../data/raw/bos_analyze/property_assess'

# %%
df_sam = pd.read_csv(filepath_sam, dtype=str)
df_prop = pd.read_csv(filepath_prop, dtype=str)

# %%
print(df_prop.info())
df_prop.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174668 entries, 0 to 174667
# Data columns (total 75 columns):
# PID                174668 non-null object
# CM_ID              82038 non-null object
# GIS_ID             174668 non-null object
# ST_NUM             174668 non-null object
# ST_NAME            174668 non-null object
# ST_NAME_SUF        174129 non-null object
# UNIT_NUM           65700 non-null object
# ZIPCODE            174661 non-null object
# PTYPE              174668 non-null object
# LU                 174668 non-null object
# OWN_OCC            174668 non-null object
# OWNER              174668 non-null object
# MAIL_ADDRESSEE     174668 non-null object
# MAIL_ADDRESS       174668 non-null object
# MAIL CS            174668 non-null object
# MAIL_ZIPCODE       174668 non-null object
# AV_LAND            174668 non-null object
# AV_BLDG            174668 non-null object
# AV_TOTAL           174668 non-null object
# GROSS_TAX          174668 non-null object
# LAND_SF            169227 non-null object
# YR_BUILT           169454 non-null object
# YR_REMOD           132872 non-null object
# GROSS_AREA         169140 non-null object
# LIVING_AREA        169140 non-null object
# NUM_FLOORS         152139 non-null object
# STRUCTURE_CLASS    84501 non-null object
# R_BLDG_STYL        62760 non-null object
# R_ROOF_TYP         62757 non-null object
# R_EXT_FIN          62757 non-null object
# R_TOTAL_RMS        62757 non-null object
# R_BDRMS            62757 non-null object
# R_FULL_BTH         62757 non-null object
# R_HALF_BTH         62757 non-null object
# R_BTH_STYLE        62757 non-null object
# R_BTH_STYLE2       54762 non-null object
# R_BTH_STYLE3       27184 non-null object
# R_KITCH            62757 non-null object
# R_KITCH_STYLE      62757 non-null object
# R_KITCH_STYLE2     32829 non-null object
# R_KITCH_STYLE3     14566 non-null object
# R_HEAT_TYP         62757 non-null object
# R_AC               62757 non-null object
# R_FPLACE           62757 non-null object
# R_EXT_CND          62757 non-null object
# R_OVRALL_CND       62757 non-null object
# R_INT_CND          62757 non-null object
# R_INT_FIN          62757 non-null object
# R_VIEW             62757 non-null object
# S_NUM_BLDG         3567 non-null object
# S_BLDG_STYL        9930 non-null object
# S_UNIT_RES         9930 non-null object
# S_UNIT_COM         9930 non-null object
# S_UNIT_RC          9930 non-null object
# S_EXT_FIN          9930 non-null object
# S_EXT_CND          9930 non-null object
# U_BASE_FLOOR       64044 non-null object
# U_NUM_PARK         64044 non-null object
# U_CORNER           64044 non-null object
# U_ORIENT           64044 non-null object
# U_TOT_RMS          64044 non-null object
# U_BDRMS            64044 non-null object
# U_FULL_BTH         64044 non-null object
# U_HALF_BTH         64044 non-null object
# U_BTH_STYLE        64044 non-null object
# U_BTH_STYLE2       25469 non-null object
# U_BTH_STYLE3       6930 non-null object
# U_KITCH_TYPE       64044 non-null object
# U_KITCH_STYLE      64044 non-null object
# U_HEAT_TYP         64044 non-null object
# U_AC               64044 non-null object
# U_FPLACE           64044 non-null object
# U_INT_FIN          64044 non-null object
# U_INT_CND          64044 non-null object
# U_VIEW             64044 non-null object
# dtypes: object(75)
# memory usage: 99.9+ MB
# None
#           PID      CM_ID     GIS_ID ST_NUM ST_NAME ST_NAME_SUF UNIT_NUM  \
# 0  0502550008  502550000  502550000     87  BEACON          ST      2-F
# 1  0502550010  502550000  502550000     87  BEACON          ST      2-R
# 2  0502550012  502550000  502550000     87  BEACON          ST      3-F
# 3  0502550014  502550000  502550000     87  BEACON          ST      3-R
# 4  0502550016  502550000  502550000     87  BEACON          ST        4
#
#   ZIPCODE PTYPE  LU  ... U_BTH_STYLE2 U_BTH_STYLE3 U_KITCH_TYPE U_KITCH_STYLE  \
# 0    2108   102  CD  ...            M          NaN            O             M
# 1    2108   102  CD  ...          NaN          NaN            O             S
# 2    2108   102  CD  ...            S          NaN            O             M
# 3    2108   102  CD  ...          NaN          NaN            O             N
# 4    2108   102  CD  ...            M            M            O             L
#
#   U_HEAT_TYP U_AC U_FPLACE U_INT_FIN U_INT_CND U_VIEW
# 0          W    N        1         N         G      A
# 1          W    N        1         N         A      A
# 2          W    N        1         N         A      G
# 3          W    N        1         S         A      G
# 4          W    C        2         N         E      G
#
# [5 rows x 75 columns]

# %%
df_prop['ZIPCODE'] = '0' + df_prop['ZIPCODE']
df_prop['is_prop'] = 1
df_sam['is_sam'] = 1
df_sam['GIS_ID'] = df_sam['PARCEL'].copy().str[1:]

# %%
print(df_sam.info())
df_sam.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398702 entries, 0 to 398701
# Data columns (total 31 columns):
# X                       398702 non-null object
# Y                       398702 non-null object
# SAM_ADDRESS_ID          398702 non-null object
# RELATIONSHIP_TYPE       398702 non-null object
# BUILDING_ID             398702 non-null object
# FULL_ADDRESS            398702 non-null object
# STREET_NUMBER           398702 non-null object
# IS_RANGE                398702 non-null object
# RANGE_FROM              26175 non-null object
# RANGE_TO                26175 non-null object
# UNIT                    270100 non-null object
# FULL_STREET_NAME        398702 non-null object
# STREET_ID               398702 non-null object
# STREET_PREFIX           398702 non-null object
# STREET_BODY             398702 non-null object
# STREET_SUFFIX_ABBR      394519 non-null object
# STREET_FULL_SUFFIX      394519 non-null object
# STREET_SUFFIX_DIR       398702 non-null object
# STREET_NUMBER_SORT      398702 non-null object
# MAILING_NEIGHBORHOOD    398672 non-null object
# ZIP_CODE                398700 non-null object
# X_COORD                 398702 non-null object
# Y_COORD                 398702 non-null object
# SAM_STREET_ID           398702 non-null object
# WARD                    398702 non-null object
# PRECINCT_WARD           395812 non-null object
# PARCEL                  398467 non-null object
# is_sam                  398702 non-null int64
# PID                     398467 non-null object
# CM_ID                   398467 non-null object
# GIS_ID                  398467 non-null object
# dtypes: int64(1), object(30)
# memory usage: 94.3+ MB
# None
#                      X                   Y SAM_ADDRESS_ID RELATIONSHIP_TYPE  \
# 0  -71.125036547600004  42.250626552299998              1                 1
# 1       -71.1248914926  42.250328423299997              2                 1
# 2        -71.125400606  42.250468650199998              4                 1
# 3  -71.056800588499996  42.340888670200002             11                 1
# 4  -71.053148588300004       42.3448456709             16                 1
#
#   BUILDING_ID  FULL_ADDRESS STREET_NUMBER IS_RANGE RANGE_FROM RANGE_TO  ...  \
# 0      100778     6-10 A St          6-10        1          6       10  ...
# 1      126344       15 A St            15        0        NaN      NaN  ...
# 2      100797        7 A St             7        0        NaN      NaN  ...
# 3      154909       10 A St            10        0        NaN      NaN  ...
# 4      141250  172-174 A St       172-174        1        172      174  ...
#
#             X_COORD           Y_COORD SAM_STREET_ID WARD PRECINCT_WARD  \
# 0  757684.428549561  2916575.26204486             1   18          1818
# 1  757724.178237994   2916466.7927758             1   18          1818
# 2  757586.116749272   2916517.2874641             1   18          1818
# 3   775987.55932641  2949556.68074288             2   06          0601
# 4  776967.328447327  2951003.83399223             2   06          0601
#
#        PARCEL is_sam        PID      CM_ID     GIS_ID
# 0  1809309000      1  809309000  809309000  809309000
# 1  1809331000      1  809331000  809331000  809331000
# 2  1809337000      1  809337000  809337000  809337000
# 3  0600090000      1  600090000  600090000  600090000
# 4  0602743000      1  602743000  602743000  602743000
#
# [5 rows x 31 columns]

# %%
df_sam_unique = df_sam.groupby('GIS_ID').agg(
    {
        'X': 'first',
        'Y': 'first',
        'X_COORD': 'first',
        'Y_COORD': 'first',
        'is_sam': 'first',
        'is_sam': np.sum
    }
)

# %%
df_sam_unique.shape
# Out:
# (66783, 5)

# %%
df_sam_unique.tail()
# Out:
#                              X                   Y           X_COORD  \
# GIS_ID
# 905095000  -71.118380606200006  42.290288658100003  759421.780110985
# 905097000  -71.118650606100005  42.290328658100002  759348.661454916
# 905098000  -71.118900606099999  42.290338658499998  759281.003054842
# 905100000       -71.1184306058  42.290038658199997  759408.659342974
# 905101000  -71.118450605800007        42.289918658  759403.443566963
#
#                     Y_COORD  is_sam
# GIS_ID
# 905095000  2931036.67317362       4
# 905097000  2931050.92306164       4
# 905098000  2931054.26504564       1
# 905100000  2930945.50888555       4
# 905101000   2930901.7547735       4

# %%
# df_merge = pd.merge(df_prop[['CM_ID', 'is_prop']], df_sam[['CM_ID', 'is_sam']], on='CM_ID', how='left')

# %%
df_merge = pd.merge(df_prop, df_sam_unique, on='GIS_ID', how='left')

# %%
df_merge.info()
df_merge.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174668 entries, 0 to 174667
# Data columns (total 81 columns):
# PID                174668 non-null object
# CM_ID              82038 non-null object
# GIS_ID             174668 non-null object
# ST_NUM             174668 non-null object
# ST_NAME            174668 non-null object
# ST_NAME_SUF        174129 non-null object
# UNIT_NUM           65700 non-null object
# ZIPCODE            174661 non-null object
# PTYPE              174668 non-null object
# LU                 174668 non-null object
# OWN_OCC            174668 non-null object
# OWNER              174668 non-null object
# MAIL_ADDRESSEE     174668 non-null object
# MAIL_ADDRESS       174668 non-null object
# MAIL CS            174668 non-null object
# MAIL_ZIPCODE       174668 non-null object
# AV_LAND            174668 non-null object
# AV_BLDG            174668 non-null object
# AV_TOTAL           174668 non-null object
# GROSS_TAX          174668 non-null object
# LAND_SF            169227 non-null object
# YR_BUILT           169454 non-null object
# YR_REMOD           132872 non-null object
# GROSS_AREA         169140 non-null object
# LIVING_AREA        169140 non-null object
# NUM_FLOORS         152139 non-null object
# STRUCTURE_CLASS    84501 non-null object
# R_BLDG_STYL        62760 non-null object
# R_ROOF_TYP         62757 non-null object
# R_EXT_FIN          62757 non-null object
# R_TOTAL_RMS        62757 non-null object
# R_BDRMS            62757 non-null object
# R_FULL_BTH         62757 non-null object
# R_HALF_BTH         62757 non-null object
# R_BTH_STYLE        62757 non-null object
# R_BTH_STYLE2       54762 non-null object
# R_BTH_STYLE3       27184 non-null object
# R_KITCH            62757 non-null object
# R_KITCH_STYLE      62757 non-null object
# R_KITCH_STYLE2     32829 non-null object
# R_KITCH_STYLE3     14566 non-null object
# R_HEAT_TYP         62757 non-null object
# R_AC               62757 non-null object
# R_FPLACE           62757 non-null object
# R_EXT_CND          62757 non-null object
# R_OVRALL_CND       62757 non-null object
# R_INT_CND          62757 non-null object
# R_INT_FIN          62757 non-null object
# R_VIEW             62757 non-null object
# S_NUM_BLDG         3567 non-null object
# S_BLDG_STYL        9930 non-null object
# S_UNIT_RES         9930 non-null object
# S_UNIT_COM         9930 non-null object
# S_UNIT_RC          9930 non-null object
# S_EXT_FIN          9930 non-null object
# S_EXT_CND          9930 non-null object
# U_BASE_FLOOR       64044 non-null object
# U_NUM_PARK         64044 non-null object
# U_CORNER           64044 non-null object
# U_ORIENT           64044 non-null object
# U_TOT_RMS          64044 non-null object
# U_BDRMS            64044 non-null object
# U_FULL_BTH         64044 non-null object
# U_HALF_BTH         64044 non-null object
# U_BTH_STYLE        64044 non-null object
# U_BTH_STYLE2       25469 non-null object
# U_BTH_STYLE3       6930 non-null object
# U_KITCH_TYPE       64044 non-null object
# U_KITCH_STYLE      64044 non-null object
# U_HEAT_TYP         64044 non-null object
# U_AC               64044 non-null object
# U_FPLACE           64044 non-null object
# U_INT_FIN          64044 non-null object
# U_INT_CND          64044 non-null object
# U_VIEW             64044 non-null object
# is_prop            174668 non-null int64
# X                  73795 non-null object
# Y                  73795 non-null object
# X_COORD            73795 non-null object
# Y_COORD            73795 non-null object
# is_sam             73795 non-null float64
# dtypes: float64(1), int64(1), object(79)
# memory usage: 109.3+ MB
#           PID      CM_ID     GIS_ID ST_NUM ST_NAME ST_NAME_SUF UNIT_NUM  \
# 0  0502550008  502550000  502550000     87  BEACON          ST      2-F
# 1  0502550010  502550000  502550000     87  BEACON          ST      2-R
# 2  0502550012  502550000  502550000     87  BEACON          ST      3-F
# 3  0502550014  502550000  502550000     87  BEACON          ST      3-R
# 4  0502550016  502550000  502550000     87  BEACON          ST        4
# 5  0502551000  502551000  502551000     88  BEACON          ST      NaN
# 6  0502551002  502551000  502551000     88  BEACON          ST        1
# 7  0502551004  502551000  502551000     88  BEACON          ST        2
# 8  0502551006  502551000  502551000     88  BEACON          ST        3
# 9  0502551008  502551000  502551000     88  BEACON          ST        4
#
#          ZIPCODE PTYPE  LU  ... U_FPLACE U_INT_FIN U_INT_CND U_VIEW is_prop  \
# 0  0000000002108   102  CD  ...        1         N         G      A       1
# 1  0000000002108   102  CD  ...        1         N         A      A       1
# 2  0000000002108   102  CD  ...        1         N         A      G       1
# 3  0000000002108   102  CD  ...        1         S         A      G       1
# 4  0000000002108   102  CD  ...        2         N         E      G       1
# 5  0000000002108   995  CM  ...      NaN       NaN       NaN    NaN       1
# 6  0000000002108   102  CD  ...        0         N         A      F       1
# 7  0000000002108   102  CD  ...        1         N         A      F       1
# 8  0000000002108   102  CD  ...        2         E         E      E       1
# 9  0000000002108   102  CD  ...        0         N         A      E       1
#
#                      X             Y           X_COORD           Y_COORD  \
# 0  -71.071690594499998  42.355918672   771934.51881063  2955013.33005996
# 1  -71.071690594499998  42.355918672   771934.51881063  2955013.33005996
# 2  -71.071690594499998  42.355918672   771934.51881063  2955013.33005996
# 3  -71.071690594499998  42.355918672   771934.51881063  2955013.33005996
# 4  -71.071690594499998  42.355918672   771934.51881063  2955013.33005996
# 5  -71.071790594600003  42.355898672  771907.526618615  2955005.90596394
# 6  -71.071790594600003  42.355898672  771907.526618615  2955005.90596394
# 7  -71.071790594600003  42.355898672  771907.526618615  2955005.90596394
# 8  -71.071790594600003  42.355898672  771907.526618615  2955005.90596394
# 9  -71.071790594600003  42.355898672  771907.526618615  2955005.90596394
#
#   is_sam
# 0   16.0
# 1   16.0
# 2   16.0
# 3   16.0
# 4   16.0
# 5    7.0
# 6    7.0
# 7    7.0
# 8    7.0
# 9    7.0
#
# [10 rows x 81 columns]

# %%
df_merge['is_prop'].sum()
# Out:
# 174668

# %%
df_merge[df_merge['is_sam'].isnull()]
# Out:
#                PID       CM_ID      GIS_ID     ST_NUM              ST_NAME  \
# 312     0100179002         NaN   100179002                       PRINCETON
# 441     0100289000         NaN   100289000                       PRINCETON
# 442     0100290000         NaN   100290000                       PRINCETON
# 483     0100335000         NaN   100335000                          BREMEN
# 492     0100344000         NaN   100344000        368               BREMEN
# 497     0100352000         NaN   100352000                         NEPTUNE
# 499     0100357000         NaN   100357000         36              NEPTUNE
# 502     0100359001         NaN   100359001        405            FRANKFORT
# 503     0100359002         NaN   100359002        409            FRANKFORT
# 504     0100359005         NaN   100359005                         NEPTUNE
# 505     0100359010         NaN   100359010                         NEPTUNE
# 507     0100365010         NaN   100365010                       FRANKFORT
# 534     0100401001         NaN   100401001                          VIENNA
# 544     0100411010         NaN   100411010                      BENNINGTON
# 552     0100422001         NaN   100422001                       FRANKFORT
# 553     0100428010         NaN   100428010                       FRANKFORT
# 558     0100432001         NaN   100432001                       FRANKFORT
# 559     0100432002         NaN   100432002                       FRANKFORT
# 564     0100435010         NaN   100435010             BOSTON AND MAINE RR
# 566     0100436001         NaN   100436001             BOSTON AND MAINE RR
# 567     0100436003         NaN   100436001                  WM F MCCLELLAN
# 569     0100437100         NaN   100437100                  WM F MCCLELLAN
# 573     0100439020         NaN   100439020                         CHELSEA
# 574     0100439030         NaN   100439030        611              CHELSEA
# 575     0100440010         NaN   100440010        605              CHELSEA
# 576     0100441010         NaN   100441010        545              CHELSEA
# 577     0100441060         NaN   100441060                         CHELSEA
# 578     0100441100         NaN   100441100        525              CHELSEA
# 615     0100478000         NaN   100478000        415              CHELSEA
# 621     0100485010         NaN   100485010                  WM F MCCLELLAN
# ...            ...         ...         ...        ...                  ...
# 174638  2205652003         NaN  2205652003     30 30R               UNDINE
# 174639  2205652003         NaN  2205652003     30 30R               UNDINE
# 174640  2205652005         NaN  2205652005        3 5               CALTHA
# 174641  2205652007         NaN  2205652007        7 9               CALTHA
# 174642  2205652008         NaN  2205652008      11 15               CALTHA
# 174643  2205652009         NaN  2205652009      17 19               CALTHA
# 174644  2205652010         NaN  2205652010      21 23               CALTHA
# 174645  2205653000         NaN  2205653000      20 22               CALTHA
# 174646  2205654000         NaN  2205654000      16 18               CALTHA
# 174647  2205655000         NaN  2205655000         14               CALTHA
# 174648  2205656000         NaN  2205656000         10               CALTHA
# 174649  2205657000         NaN  2205657000          6               CALTHA
# 174650  2205658000         NaN  2205658000          2               CALTHA
# 174651  2205659000         NaN  2205659000         34                 LAKE
# 174652  2205660000         NaN  2205660000         30                 LAKE
# 174653  2205662010         NaN  2205662010         26                 LAKE
# 174654  2205662020         NaN  2205662020         24                 LAKE
# 174655  2205663000         NaN  2205663000         22                 LAKE
# 174656  2205663001         NaN  2205663001         20                 LAKE
# 174657  2205664000         NaN  2205664000      18 16                 LAKE
# 174658  2205665000  2205665000  2205665000      14 12                 LAKE
# 174659  2205665002  2205665000  2205665000         14                 LAKE
# 174660  2205665004  2205665000  2205665000         12                 LAKE
# 174661  2205666000         NaN  2205666000                         KNOWLES
# 174662  2205667000         NaN  2205667000                            LAKE
# 174663  2205668000         NaN  2205668000          4                 LAKE
# 174664  2205669000         NaN  2205669000  2193 2201         COMMONWEALTH
# 174665  2205670000         NaN  2205670000       2203         COMMONWEALTH
# 174666  2205670000         NaN  2205670000       2203         COMMONWEALTH
# 174667  2205670000         NaN  2205670000       2203         COMMONWEALTH
#
#        ST_NAME_SUF UNIT_NUM        ZIPCODE PTYPE  LU  ... U_FPLACE U_INT_FIN  \
# 312             ST      NaN  0000000002128   132  RL  ...      NaN       NaN
# 441             ST      NaN  0000000002128   106  RL  ...      NaN       NaN
# 442             ST      NaN  0000000002128   316   C  ...      NaN       NaN
# 483             ST      NaN  0000000002128   337  CL  ...      NaN       NaN
# 492             ST      NaN  0000000002128   337  CL  ...      NaN       NaN
# 497             RD      NaN  0000000002128   985   E  ...      NaN       NaN
# 499             RD      NaN  0000000002128   985   E  ...      NaN       NaN
# 502             ST      NaN  0000000002128   902   E  ...      NaN       NaN
# 503             ST      NaN  0000000002128   985   E  ...      NaN       NaN
# 504             RD      NaN  0000000002128   901   E  ...      NaN       NaN
# 505             RD      NaN  0000000002128   901   E  ...      NaN       NaN
# 507             ST      NaN  0000000002128   986   E  ...      NaN       NaN
# 534             ST      NaN  0000000002128   902   E  ...      NaN       NaN
# 544             ST      NaN  0000000002128   985   E  ...      NaN       NaN
# 552             ST      NaN  0000000002128   132  RL  ...      NaN       NaN
# 553             ST      NaN  0000000002128   986   E  ...      NaN       NaN
# 558             ST      NaN  0000000002128   901   E  ...      NaN       NaN
# 559             ST      NaN  0000000002128   901   E  ...      NaN       NaN
# 564                     NaN  0000000002128   902   E  ...      NaN       NaN
# 566                     NaN  0000000002128   986   E  ...      NaN       NaN
# 567             HW      NaN  0000000002128   465   C  ...      NaN       NaN
# 569             HW      NaN  0000000002128   986   E  ...      NaN       NaN
# 573             ST      NaN  0000000002128   985   E  ...      NaN       NaN
# 574             ST      NaN  0000000002128   986   E  ...      NaN       NaN
# 575             ST      NaN  0000000002128   446   I  ...      NaN       NaN
# 576             ST      NaN  0000000002128   420   I  ...      NaN       NaN
# 577             ST      NaN  0000000002128   986   E  ...      NaN       NaN
# 578             ST      NaN  0000000002128   420   I  ...      NaN       NaN
# 615             ST      NaN  0000000002128   390  CL  ...      NaN       NaN
# 621             HW      NaN  0000000002128   986   E  ...      NaN       NaN
# ...            ...      ...            ...   ...  ..  ...      ...       ...
# 174638          RD      NaN  0000000002135   979   E  ...      NaN       NaN
# 174639          RD      NaN  0000000002135   979   E  ...      NaN       NaN
# 174640          RD      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174641          RD      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174642          RD      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174643          RD      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174644          RD      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174645          RD      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174646          RD      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174647          RD      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174648          RD      NaN  0000000002135   101  R1  ...      NaN       NaN
# 174649          RD      NaN  0000000002135   101  R1  ...      NaN       NaN
# 174650          RD      NaN  0000000002135   101  R1  ...      NaN       NaN
# 174651          ST      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174652          ST      NaN  0000000002135   101  R1  ...      NaN       NaN
# 174653          ST      NaN  0000000002135   101  R1  ...      NaN       NaN
# 174654          ST      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174655          ST      NaN  0000000002135   101  R1  ...      NaN       NaN
# 174656          ST      NaN  0000000002135   101  R1  ...      NaN       NaN
# 174657          ST      NaN  0000000002135   104  R2  ...      NaN       NaN
# 174658          ST      NaN  0000000002135   995  CM  ...      NaN       NaN
# 174659          ST        2  0000000002135   102  CD  ...        1         N
# 174660          ST        1  0000000002135   102  CD  ...        1         N
# 174661          ST      NaN  0000000002135   902   E  ...      NaN       NaN
# 174662          ST      NaN  0000000002135   132  RL  ...      NaN       NaN
# 174663          ST      NaN  0000000002135   105  R3  ...      NaN       NaN
# 174664          AV      NaN  0000000002135   319   C  ...      NaN       NaN
# 174665          AV      NaN  0000000002135   985   E  ...      NaN       NaN
# 174666          AV      NaN  0000000002135   985   E  ...      NaN       NaN
# 174667          AV      NaN  0000000002135   985   E  ...      NaN       NaN
#
#        U_INT_CND U_VIEW is_prop    X    Y X_COORD Y_COORD is_sam
# 312          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 441          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 442          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 483          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 492          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 497          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 499          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 502          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 503          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 504          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 505          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 507          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 534          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 544          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 552          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 553          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 558          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 559          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 564          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 566          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 567          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 569          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 573          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 574          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 575          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 576          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 577          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 578          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 615          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 621          NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# ...          ...    ...     ...  ...  ...     ...     ...    ...
# 174638       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174639       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174640       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174641       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174642       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174643       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174644       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174645       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174646       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174647       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174648       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174649       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174650       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174651       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174652       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174653       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174654       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174655       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174656       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174657       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174658       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174659         A      A       1  NaN  NaN     NaN     NaN    NaN
# 174660         A      A       1  NaN  NaN     NaN     NaN    NaN
# 174661       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174662       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174663       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174664       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174665       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174666       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
# 174667       NaN    NaN       1  NaN  NaN     NaN     NaN    NaN
#
# [100873 rows x 81 columns]

# %%
len(df_merge.loc[df_merge[['is_prop', 'is_sam']].sum(axis=1)==2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-fc2655534940> in <module>
# ----> 1 len(df_merge.loc[df_merge[['is_prop', 'is_sam']].sum(axis=1)==2])
#
# ~/anaconda3/envs/cs109a/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/cs109a/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~/anaconda3/envs/cs109a/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~/anaconda3/envs/cs109a/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['is_sam'] not in index"

# %%
df_prop['ST_NUM'].value_counts()
# Out:
#               9445
# 1             2376
# 15            2337
# 10            2028
# 9             1958
# 2             1898
# 11            1804
# 8             1769
# 6             1721
# 25            1549
# 7             1532
# 12            1531
# 5             1515
# 19            1506
# 21            1478
# 20            1441
# 16            1405
# 14            1384
# 22            1375
# 18            1254
# 35            1253
# 3             1235
# 17            1224
# 4             1170
# 26            1129
# 24            1118
# 30            1113
# 27            1088
# 42            1047
# 40            1043
#               ...
# 55 W             1
# 425 A425         1
# 1110 A1108       1
# 51 - 53          1
# 199 -203         1
# 2 D              1
# 336 344          1
# 1 21             1
# 109 109A         1
# 41 -49           1
# 2521             1
# 1935             1
# 46 46R           1
# 1062 1064        1
# 695 A            1
# 401 405          1
# 24 2             1
# 662 A666A        1
# 53 HF            1
# 798 A            1
# 312 310          1
# 303 305B         1
# 1891 1893        1
# 711 715A         1
# 81 117           1
# 1090 1092        1
# 263 263H         1
# 474 474A         1
# 352 350A         1
# 302 300          1
# Name: ST_NUM, Length: 9670, dtype: int64

# %%
df_sam['STREET_NUMBER'].value_counts()
# Out:
# 1            6649
# 10           5470
# 15           5224
# 11           5142
# 9            4221
# 6            4113
# 8            4085
# 20           3926
# 7            3898
# 5            3705
# 16           3642
# 25           3636
# 12           3633
# 14           3567
# 19           3559
# 30           3558
# 2            3494
# 4            3284
# 21           3171
# 40           3131
# 35           3048
# 24           3035
# 17           3002
# 3            2904
# 26           2849
# 18           2828
# 28           2806
# 31           2658
# 27           2613
# 22           2612
#              ...
# 554-560         1
# 874-880         1
# 3359-3365       1
# 57-6            1
# 3280-3288       1
# 580-590         1
# 511R            1
# 377-385         1
# 661B            1
# 232-236A        1
# 720A-720        1
# 1536-1538       1
# 25H             1
# 18B             1
# 119-119B        1
# 406-406         1
# 349-363         1
# 4446-4448       1
# 216-238         1
# 1866-1872       1
# 12 -14          1
# 8D              1
# 3134            1
# 1818            1
# 614-618         1
# 150-180         1
# 3251-3257       1
# 908-910         1
# 270-270A        1
# 313-319         1
# Name: STREET_NUMBER, Length: 11575, dtype: int64

# %%
df_sam['FULL_STREET_NAME']
# Out:
# 0                 A St
# 1                 A St
# 2                 A St
# 3                 A St
# 4                 A St
# 5                 A St
# 6                 A St
# 7                 A St
# 8                 A St
# 9                 A St
# 10                A St
# 11                A St
# 12                A St
# 13                A St
# 14                A St
# 15                A St
# 16                A St
# 17                A St
# 18                A St
# 19                A St
# 20                A St
# 21                A St
# 22                A St
# 23                A St
# 24                A St
# 25                A St
# 26                A St
# 27                A St
# 28                A St
# 29                A St
#               ...
# 398672    Harrison Ave
# 398673    Harrison Ave
# 398674    Harrison Ave
# 398675    Harrison Ave
# 398676    Harrison Ave
# 398677    Harrison Ave
# 398678    Harrison Ave
# 398679    Harrison Ave
# 398680    Harrison Ave
# 398681    Harrison Ave
# 398682    Harrison Ave
# 398683    Harrison Ave
# 398684    Harrison Ave
# 398685    Harrison Ave
# 398686    Harrison Ave
# 398687    Harrison Ave
# 398688    Harrison Ave
# 398689    Harrison Ave
# 398690    Harrison Ave
# 398691    Harrison Ave
# 398692    Harrison Ave
# 398693    Harrison Ave
# 398694    Harrison Ave
# 398695    Harrison Ave
# 398696    Harrison Ave
# 398697    Harrison Ave
# 398698    Harrison Ave
# 398699    Harrison Ave
# 398700    Harrison Ave
# 398701    Harrison Ave
# Name: FULL_STREET_NAME, Length: 398702, dtype: object

# %%
df_sam.loc[df_sam['FULL_STREET_NAME'].str.contains('Beacon')]['STREET_NUMBER'].value_counts().sort_index().loc['87']
# Out:
# 16

# %%
df_prop.loc[(df_prop['ST_NAME'].str.contains('BEACON')) & (df_prop['ST_NUM']=='87')]
# Out:
#               PID      CM_ID     GIS_ID ST_NUM ST_NAME ST_NAME_SUF UNIT_NUM  \
# 0      0502550008  502550000  502550000     87  BEACON          ST      2-F
# 1      0502550010  502550000  502550000     87  BEACON          ST      2-R
# 2      0502550012  502550000  502550000     87  BEACON          ST      3-F
# 3      0502550014  502550000  502550000     87  BEACON          ST      3-R
# 4      0502550016  502550000  502550000     87  BEACON          ST        4
# 45818  0502550000  502550000  502550000     87  BEACON          ST      NaN
# 45819  0502550002  502550000  502550000     87  BEACON          ST      G-1
# 45820  0502550004  502550000  502550000     87  BEACON          ST        1
#
#           ZIPCODE PTYPE  LU  ... U_BTH_STYLE3 U_KITCH_TYPE U_KITCH_STYLE  \
# 0      0000002108   102  CD  ...          NaN            O             M
# 1      0000002108   102  CD  ...          NaN            O             S
# 2      0000002108   102  CD  ...          NaN            O             M
# 3      0000002108   102  CD  ...          NaN            O             N
# 4      0000002108   102  CD  ...            M            O             L
# 45818  0000002108   995  CM  ...          NaN          NaN           NaN
# 45819  0000002108   102  CD  ...          NaN            O             M
# 45820  0000002108   102  CD  ...          NaN            O             M
#
#       U_HEAT_TYP U_AC U_FPLACE U_INT_FIN U_INT_CND U_VIEW is_prop
# 0              W    N        1         N         G      A       1
# 1              W    N        1         N         A      A       1
# 2              W    N        1         N         A      G       1
# 3              W    N        1         S         A      G       1
# 4              W    C        2         N         E      G       1
# 45818        NaN  NaN      NaN       NaN       NaN    NaN       1
# 45819          W    N        0         N         G      A       1
# 45820          W    C        1         N         G      A       1
#
# [8 rows x 76 columns]

# %%
df_sam.loc[(df_sam['FULL_STREET_NAME'].str.contains('Beacon')) & (df_sam['STREET_NUMBER']=='87')]#['ZIP_CODE']#[['STREET_NUMBER', 'PARCEL', 'CM_ID']]
# Out:
#                           X                   Y SAM_ADDRESS_ID  \
# 8856    -71.071690594499998        42.355918672          12344
# 8857    -71.071690594499998        42.355918672          12345
# 8858    -71.071690594499998        42.355918672          12346
# 8859    -71.071690594499998        42.355918672          12347
# 8860    -71.071690594499998        42.355918672          12348
# 8861    -71.071690594499998        42.355918672          12349
# 8862    -71.071690594499998        42.355918672          12350
# 8863    -71.071690594499998        42.355918672          12351
# 321165  -71.071690594700001  42.355918672199998         356456
# 321166  -71.071690594700001  42.355918672199998         356457
# 321167  -71.071690594700001  42.355918672199998         356458
# 321168  -71.071690594700001  42.355918672199998         356459
# 321169  -71.071690594700001  42.355918672199998         356460
# 321170  -71.071690594700001  42.355918672199998         356461
# 321171  -71.071690594700001  42.355918672199998         356462
# 321176  -71.071690594700001  42.355918672199998         356467
#
#        RELATIONSHIP_TYPE BUILDING_ID      FULL_ADDRESS STREET_NUMBER IS_RANGE  \
# 8856                   1      139636      87 Beacon St            87        0
# 8857                   2      139636  87 Beacon St #G1            87        0
# 8858                   2      139636   87 Beacon St #1            87        0
# 8859                   2      139636  87 Beacon St #2F            87        0
# 8860                   2      139636  87 Beacon St #2R            87        0
# 8861                   2      139636  87 Beacon St #3F            87        0
# 8862                   2      139636  87 Beacon St #3R            87        0
# 8863                   2      139636   87 Beacon St #4            87        0
# 321165                 2      139636   87 Beacon St #2            87        0
# 321166                 2      139636   87 Beacon St #3            87        0
# 321167                 2      139636   87 Beacon St #5            87        0
# 321168                 2      139636   87 Beacon St #6            87        0
# 321169                 2      139636  87 Beacon St #1G            87        0
# 321170                 2      139636   87 Beacon St #8            87        0
# 321171                 2      139636   87 Beacon St #9            87        0
# 321176                 2      139636   87 Beacon St #7            87        0
#
#        RANGE_FROM RANGE_TO  ... ZIP_CODE           X_COORD           Y_COORD  \
# 8856          NaN      NaN  ...    02108   771934.51881063  2955013.33005996
# 8857          NaN      NaN  ...    02108   771934.51881063  2955013.33005996
# 8858          NaN      NaN  ...    02108   771934.51881063  2955013.33005996
# 8859          NaN      NaN  ...    02108   771934.51881063  2955013.33005996
# 8860          NaN      NaN  ...    02108   771934.51881063  2955013.33005996
# 8861          NaN      NaN  ...    02108   771934.51881063  2955013.33005996
# 8862          NaN      NaN  ...    02108   771934.51881063  2955013.33005996
# 8863          NaN      NaN  ...    02108   771934.51881063  2955013.33005996
# 321165        NaN      NaN  ...    02108  771934.518766137   2955013.3301314
# 321166        NaN      NaN  ...    02108  771934.518766137   2955013.3301314
# 321167        NaN      NaN  ...    02108  771934.518766137   2955013.3301314
# 321168        NaN      NaN  ...    02108  771934.518766137   2955013.3301314
# 321169        NaN      NaN  ...    02108  771934.518766137   2955013.3301314
# 321170        NaN      NaN  ...    02108  771934.518766137   2955013.3301314
# 321171        NaN      NaN  ...    02108  771934.518766137   2955013.3301314
# 321176        NaN      NaN  ...    02108  771934.518766137   2955013.3301314
#
#        SAM_STREET_ID WARD PRECINCT_WARD      PARCEL is_sam        PID  \
# 8856             332   05          0505  0502550000      1  502550000
# 8857             332   05          0505  0502550000      1  502550000
# 8858             332   05          0505  0502550000      1  502550000
# 8859             332   05          0505  0502550000      1  502550000
# 8860             332   05          0505  0502550000      1  502550000
# 8861             332   05          0505  0502550000      1  502550000
# 8862             332   05          0505  0502550000      1  502550000
# 8863             332   05          0505  0502550000      1  502550000
# 321165           332   05          0505  0502550000      1  502550000
# 321166           332   05          0505  0502550000      1  502550000
# 321167           332   05          0505  0502550000      1  502550000
# 321168           332   05          0505  0502550000      1  502550000
# 321169           332   05          0505  0502550000      1  502550000
# 321170           332   05          0505  0502550000      1  502550000
# 321171           332   05          0505  0502550000      1  502550000
# 321176           332   05          0505  0502550000      1  502550000
#
#             CM_ID
# 8856    502550000
# 8857    502550000
# 8858    502550000
# 8859    502550000
# 8860    502550000
# 8861    502550000
# 8862    502550000
# 8863    502550000
# 321165  502550000
# 321166  502550000
# 321167  502550000
# 321168  502550000
# 321169  502550000
# 321170  502550000
# 321171  502550000
# 321176  502550000
#
# [16 rows x 30 columns]

# %%
filepath
# Out:
# '../data/raw/bos_analyze/SAMaddresses.csv'

# %%
os.path.splitext(data_url)
# Out:
# ('http://bostonopendata-boston.opendata.arcgis.com/datasets/b6bffcace320448d96bb84eabb8a075f_0',
#  '.csv')

# %%
pathlib.Path(data_url).suffixes
# Out:
# ['.csv']

# %%
local_filename, headers = urllib.request.urlretrieve(
    'https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/695a8596-5458-442b-a017-7cd72471aade/download/fy19fullpropassess.csv',
    '../data/raw/test_prop2.csv'
)
