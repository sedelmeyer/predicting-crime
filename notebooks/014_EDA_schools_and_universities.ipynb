# %%
import urllib
import os
import operator
import pathlib
import requests
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
# %matplotlib inline

# %%
DATA_ROOT = '../data/'
FIGURES_ROOT = '../figures/schools'

READDIR_ROOT = os.path.join(DATA_ROOT, 'raw')
WRITEDIR_ROOT = os.path.join(DATA_ROOT, 'interim/crime')

readfile_crime = os.path.join(READDIR_ROOT, 'crime/crime-incidents.csv')

readfile_sam = os.path.join(READDIR_ROOT, 'boston/sam-addresses.csv')
readfile_zipshapes = os.path.join(READDIR_ROOT, 'shapefile/zipcodes/ZIP_Codes.shp')
readfile_cityshape = os.path.join(READDIR_ROOT, 'shapefile/city-boundary/City_of_Boston_Boundary.shp')
readfile_streetshapes = os.path.join(READDIR_ROOT, 'shapefile/street-segments/Boston_Street_Segments.shp')
readfile_tractshapes = os.path.join(READDIR_ROOT, 'shapefile/census-tracts/Census_2010_Tracts.shp')
readfile_hoodshapes = os.path.join(READDIR_ROOT, 'shapefile/boston-neighborhoods/Boston_Neighborhoods.shp')
readfile_zonesubshapes = os.path.join(READDIR_ROOT, 'shapefile/zoning-subdistricts/Zoning_Subdistricts.shp')

print(
    'readfile paths for datasets used in this notebook are:\n\t{}\n\t{}\n\t{}'.format(
        readfile_crime, readfile_sam, readfile_zipshapes, WRITEDIR_ROOT
    )
)
# Out:
# readfile paths for datasets used in this notebook are:
# 	../data/raw\crime/crime-incidents.csv
# 	../data/raw\boston/sam-addresses.csv
# 	../data/raw\shapefile/zipcodes/ZIP_Codes.shp

# %%
# mkdir for saving figures if they don't already exist
if not os.path.exists('../figures/schools'):
    os.mkdir('../figures/schools')

# %%
DATA_ROOT = '../data/'
DATA_DIR = os.path.join(DATA_ROOT, 'raw/boston')
readfile_public_k12_schools = os.path.join(DATA_DIR, 'public-k12-schools.csv')

# %%
df_public_k12_schools = pd.read_csv(readfile_public_k12_schools)
df_public_k12_schools.head(3)
# Out:
#            X          Y  OBJECTID_1  OBJECTID  BLDG_ID        BLDG_NAME  \
# 0 -71.004121  42.388799           1         1        1       Guild Bldg
# 1 -71.030480  42.378545           2         2        3  Kennedy, P Bldg
# 2 -71.033891  42.375279           3         3        4        Otis Bldg
#
#                ADDRESS         CITY  ZIPCODE  CSP_SCH_ID  SCH_ID  \
# 0    195 Leyden Street  East Boston     2128        4061    4061
# 1  343 Saratoga Street  East Boston     2128        4541    4541
# 2    218 Marion Street  East Boston     2128        4322    4322
#
#                SCH_NAME   SCH_LABEL SCH_TYPE SHARED COMPLEX        POINT_X  \
# 0      Guild Elementary       Guild       ES                 790128.152748
# 1  Kennedy Patrick Elem  PJ Kennedy       ES                 783027.745829
# 2       Otis Elementary        Otis       ES                 782112.823908
#
#         POINT_Y
# 0  2.967094e+06
# 1  2.963318e+06
# 2  2.962122e+06

# %%
#Inspect Datatypes
df_public_k12_schools.dtypes
# Out:
# X             float64
# Y             float64
# OBJECTID_1      int64
# OBJECTID        int64
# BLDG_ID         int64
# BLDG_NAME      object
# ADDRESS        object
# CITY           object
# ZIPCODE         int64
# CSP_SCH_ID      int64
# SCH_ID          int64
# SCH_NAME       object
# SCH_LABEL      object
# SCH_TYPE       object
# SHARED         object
# COMPLEX        object
# POINT_X       float64
# POINT_Y       float64
# dtype: object

# %%
#Map plot prep

# read in SAM address data and related shapefiles
df_crime = pd.read_csv(readfile_crime, dtype=str)
df_sam = pd.read_csv(readfile_sam, dtype=str)
gdf_zips = gpd.read_file(readfile_zipshapes)
gdf_boston = gpd.read_file(readfile_cityshape)
gdf_streets = gpd.read_file(readfile_streetshapes)
gdf_tracts = gpd.read_file(readfile_tractshapes)
gdf_hoods = gpd.read_file(readfile_hoodshapes)
gdf_zonesubs = gpd.read_file(readfile_zonesubshapes)

# convert SAM data lat/lon values to floats
df_sam[['X', 'Y']] = df_sam[['X', 'Y']].astype(float)

# %%
# plot unique SAM records with city boundary and street segments overlays 
fig, ax = plt.subplots(figsize=(16,10))
gdf_boston.plot(ax=ax, color='lightgray', edgecolor='k', alpha=0.4)
gdf_streets.plot(ax=ax, color='k', linewidth=1, alpha=0.2, label='street segments')
plt.title(
    'Public K-12 Schools in the City of Boston: 131 records',
    fontsize=22
)
plt.scatter(
    df_public_k12_schools['X'], df_public_k12_schools['Y'],
    
    color='tab:blue', alpha=.5, s=10,
    label='K-12 Public Schools'
)
plt.xlabel('longitude', fontsize=14)
plt.ylabel('latitude', fontsize=14)
plt.grid(":", alpha=0.4)
plt.legend(edgecolor='k', framealpha=1, fontsize=14)
plt.tight_layout()
plt.savefig('../figures/schools/publicK12Schools.png')
plt.show();

# %%
#Add in Private Schools
readfile_non_public_k12_schools = os.path.join(DATA_DIR, 'nonpublic-k12-schools.csv')
df_non_public_k12_schools = pd.read_csv(readfile_non_public_k12_schools)
df_non_public_k12_schools.head(3)
len(df_non_public_k12_schools)
# Out:
# 82

# %%
# plot unique SAM records with city boundary and street segments overlays 
fig, ax = plt.subplots(figsize=(16,10))
gdf_boston.plot(ax=ax, color='lightgray', edgecolor='k', alpha=0.4)
gdf_streets.plot(ax=ax, color='k', linewidth=1, alpha=0.2, label='street segments')
plt.title(
    'Non-Public K-12 Schools in the City of Boston: 82 records',
    fontsize=22
)
plt.scatter(
    df_non_public_k12_schools['X'],df_non_public_k12_schools['Y'],
    
    color='tab:blue', alpha=.5, s=10,
    label='Non-Public K-12 Public Schools'
)
plt.xlabel('longitude', fontsize=14)
plt.ylabel('latitude', fontsize=14)
plt.grid(":", alpha=0.4)
plt.legend(edgecolor='k', framealpha=1, fontsize=14)
plt.tight_layout()
plt.savefig('../figures/schools/nonpublicK12Schools.png')
plt.show();

# %%
# plot public and private schools together

fig, ax = plt.subplots(figsize=(16,10))
gdf_boston.plot(ax=ax, color='lightgray', edgecolor='k', alpha=0.4)
gdf_streets.plot(ax=ax, color='k', linewidth=1, alpha=0.2, label='street segments')
plt.title(
    'Public/Private K-12 Schools in the City of Boston: 213 records',
    fontsize=22
)
plt.scatter(
    df_non_public_k12_schools['X'],df_non_public_k12_schools['Y'],
    color='tab:blue', alpha=.5, s=10,
    label='Private K-12 Public Schools'
)
plt.scatter(
    df_public_k12_schools['X'],df_public_k12_schools['Y'],
    color='tab:red', alpha=.5, s=10,
    label='Public K-12 Public Schools'
)
#plt.scatter(x, y, c='r', marker='s', label='-1')

plt.xlabel('longitude', fontsize=14)
plt.ylabel('latitude', fontsize=14)
plt.grid(":", alpha=0.4)
plt.legend(edgecolor='k', framealpha=1, fontsize=14)
plt.tight_layout()
plt.savefig('../figures/schools/publicAndPrivateK12Schools.png')
plt.show();

# %%
# add in colleges/universities
readfile_colleges_universities = os.path.join(DATA_DIR, 'colleges-universities.csv')
df_colleges_universities = pd.read_csv(readfile_colleges_universities)
df_colleges_universities.head(3)

#Check Total Records
print('Raw Coordinates: ',len(df_colleges_universities))

#Check for missing records
print('Missing Coordinates: ',len(df_colleges_universities[df_colleges_universities['Latitude'] == 0]))

#Scrubbing out missing records
missingCoords = df_colleges_universities[df_colleges_universities['Latitude'] == 0 ].index
df_colleges_universities.drop(missingCoords , inplace=True)
print('Cleansed Dataset Records: ',len(df_colleges_universities))

#Save new dataset to processed folder
df_colleges_universities.to_csv('../data/processed/colleges_universities_final.csv', sep=',')
# Out:
# Raw Coordinates:  60
# Missing Coordinates:  3
# Cleansed Dataset Records:  57

# %%
#Plot Colleges/Universities Alone

# plot public and private schools together

fig, ax = plt.subplots(figsize=(16,10))
gdf_boston.plot(ax=ax, color='lightgray', edgecolor='k', alpha=0.4)
gdf_streets.plot(ax=ax, color='k', linewidth=1, alpha=0.2, label='street segments')
plt.title(
    'Colleges/Universities in the City of Boston: 57 Records',
    fontsize=22
)
plt.scatter(
    df_colleges_universities['Longitude'],df_colleges_universities['Latitude'],
    color='tab:orange', alpha=.5, s=10,
    label='Colleges/Universities'
)

plt.xlabel('Longitude', fontsize=14)
plt.ylabel('Latitude', fontsize=14)
plt.grid(":", alpha=0.4)
plt.legend(edgecolor='k', framealpha=1, fontsize=14)
plt.tight_layout()
plt.savefig('../figures/schools/collegeUniversities.png')
plt.show();

# %%
#Add in all educational institutions
fig, ax = plt.subplots(figsize=(16,10))
gdf_boston.plot(ax=ax, color='lightgray', edgecolor='k', alpha=0.4)
gdf_streets.plot(ax=ax, color='k', linewidth=1, alpha=0.2, label='street segments')
plt.title(
    'Education Institutions in the City of Boston: 270 records',
    fontsize=22
)
plt.scatter(
    df_non_public_k12_schools['X'],df_non_public_k12_schools['Y'],
    color='tab:blue', alpha=.5, s=10,
    label='Private K-12 Public Schools'
)
plt.scatter(
    df_public_k12_schools['X'],df_public_k12_schools['Y'],
    color='tab:red', alpha=.5, s=10,
    label='Public K-12 Public Schools'
)
plt.scatter(
    df_colleges_universities['Longitude'],df_colleges_universities['Latitude'],
    color='tab:orange', alpha=.5, s=10,
    label='Colleges/Universities'
)

plt.xlabel('longitude', fontsize=14)
plt.ylabel('latitude', fontsize=14)
plt.grid(":", alpha=0.4)
plt.legend(edgecolor='k', framealpha=1, fontsize=14)
plt.tight_layout()
plt.savefig('../figures/schools/allEducationInstitutions.png')
plt.show();
